# %%
import requests
import pandas as pd
import numpy as np
import json
from urllib.request import urlopen
import pickle

# %%
def request_function(property,specie,page):
    url = (
    "http://aflowlib.duke.edu/search/API/?"
    f"{property}(!null),"
    "compound,"
    "stoichiometry,"
    f"$paging({page}),"
    f"species({specie})")
    
    r = requests.get(url)
    try:
     data = r.json()
    except:
        return pd.DataFrame()
    
    df = pd.DataFrame(data)
    return df

species = ['Cu', 'Ni','Al']
all_data = {}

for specie in species:
    data_specie = pd.DataFrame(columns=['compound','agl_thermal_conductivity_300K','stoichiometry'])

    for i in range(90):
        df = request_function("agl_thermal_conductivity_300K",specie,i)
        
        if df.empty:
            continue
        
        df_v2 = df[["compound","agl_thermal_conductivity_300K","stoichiometry"]]
        data_specie = pd.concat([data_specie,df], ignore_index=True)
    
    all_data[specie] = data_specie

## Save the dictory as a pickle document
with open("data_AFLOW.pkl","wb") as f:
    pickle.dump(all_data,f)

# %%
url="http://aflow.org/API/aflux/?agl_thermal_conductivity_300K,stoichiometry,paging(1),format(json)"

# send the request
response = requests.get(url)
data= response.json()
# convert to Dataframe
df = pd.DataFrame(data)

print(df.head())
# Out:
#                                                            1 of 2981853  \
# compound                                                      Fe2Os1Rh1
# auid                                             aflow:00b4c16987c3e675
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/Fe_pvOs_p...
# spacegroup_relax                                                    225
# Pearson_symbol_relax                                               cF16
#
#                                                            2 of 2981853  \
# compound                                                      As1In2Mn1
# auid                                             aflow:00b43697fca50909
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/AsIn_dMn_...
# spacegroup_relax                                                    123
# Pearson_symbol_relax                                                tP4
#
#                                                            3 of 2981853  \
# compound                                                      Li1Re1Ru2
# auid                                             aflow:00b49df7ca9997c5
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/Li_svRe_p...
# spacegroup_relax                                                     47
# Pearson_symbol_relax                                                oP4
#
#                                                            4 of 2981853  \
# compound                                                      Cu2Mg3Se2
# auid                                             aflow:00b41197b056e61a
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/Cu_pvMg_p...
# spacegroup_relax                                                     65
# Pearson_symbol_relax                                               oS14
#
#                                                            5 of 2981853  \
# compound                                                      Na1Pb2Te1
# auid                                             aflow:00b4ff1adbda547f
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/Na_svPb_d...
# spacegroup_relax                                                     47
# Pearson_symbol_relax                                                oP4
#
#                                                      6 of 2981853  \
# compound                                                    C1Zn1
# auid                                       aflow:00b4d04d74833514
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB2_RAW/CZn/60
# spacegroup_relax                                               65
# Pearson_symbol_relax                                          oS4
#
#                                                            7 of 2981853  \
# compound                                                      Au2Cr1Os1
# auid                                             aflow:00b43bd2569326fe
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/AuCr_pvOs...
# spacegroup_relax                                                    166
# Pearson_symbol_relax                                                hR4
#
#                                                            8 of 2981853  \
# compound                                                      Ru1Sc1Tl2
# auid                                             aflow:00b47a0b49e1ff99
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/Ru_pvSc_s...
# spacegroup_relax                                                     47
# Pearson_symbol_relax                                                oP4
#
#                                                          9 of 2981853  \
# compound                                                       Au4Bi2
# auid                                           aflow:00b47a9f8d66232f
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB2_RAW/AuBi_d/476
# spacegroup_relax                                                   12
# Pearson_symbol_relax                                             mS12
#
#                                                           10 of 2981853  ...  \
# compound                                                      Ni1Se1Zr1  ...
# auid                                             aflow:00b4497cfc1a7141  ...
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/Ni_pvSeZr...  ...
# spacegroup_relax                                                     42  ...
# Pearson_symbol_relax                                               oF12  ...
#
#                                                           55 of 2981853  \
# compound                                                       Ag2B1Ti1
# auid                                             aflow:00c110d2144b4842
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/AgB_hTi_s...
# spacegroup_relax                                                     12
# Pearson_symbol_relax                                                mS8
#
#                                                           56 of 2981853  \
# compound                                                      Cl2Re1Tl1
# auid                                             aflow:00c1093ad7e9de03
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/ClRe_pvTl...
# spacegroup_relax                                                    216
# Pearson_symbol_relax                                               cF16
#
#                                                           57 of 2981853  \
# compound                                                       Ge1P2Si1
# auid                                             aflow:00c15423b33ce0ba
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/Ge_hPSi/T...
# spacegroup_relax                                                    216
# Pearson_symbol_relax                                               cF16
#
#                                                           58 of 2981853  \
# compound                                                   Al2Li2O12Si4
# auid                                             aflow:00c18b79ed945d8e
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/MCLC/Al1L...
# spacegroup_relax                                                     15
# Pearson_symbol_relax                                               mS40
#
#                                                           59 of 2981853  \
# compound                                                      Si1Tl2Zn1
# auid                                             aflow:00c161273fcac36d
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/SiTl_dZn/...
# spacegroup_relax                                                     47
# Pearson_symbol_relax                                                oP4
#
#                                                           60 of 2981853  \
# compound                                                       Ni2P1Tl1
# auid                                             aflow:00c1ca07c7b5858f
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/Ni_pvPTl_...
# spacegroup_relax                                                     99
# Pearson_symbol_relax                                                tP4
#
#                                                           61 of 2981853  \
# compound                                                      Co1Rh2Tl2
# auid                                             aflow:00c15b11af1772dd
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/CoRh_pvTl...
# spacegroup_relax                                                    139
# Pearson_symbol_relax                                               tI10
#
#                                                           62 of 2981853  \
# compound                                                      Br1Nb2Pt1
# auid                                             aflow:00c15ba59d444266
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/BrNb_svPt...
# spacegroup_relax                                                     71
# Pearson_symbol_relax                                                oI8
#
#                                                          63 of 2981853  \
# compound                                                        Sb4Ta4
# auid                                            aflow:00c1d4c622a7d964
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB2_RAW/SbTa_pv/256
# spacegroup_relax                                                    62
# Pearson_symbol_relax                                               oP8
#
#                                                           64 of 2981853
# compound                                                       K1Mg1Si2
# auid                                             aflow:00c1daf9f3980e7e
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB3_RAW/K_svMg_pv...
# spacegroup_relax                                                     99
# Pearson_symbol_relax                                                tP4
#
# [5 rows x 64 columns]

# %%
url = (
    "http://aflowlib.duke.edu/search/API/?"
    "agl_thermal_conductivity_300K(!null),"
    "compound,"
    "stoichiometry,"
    "$paging(1),"
    "aurl"
)

# %%
data= response.json()
df = pd.DataFrame(data)
print(df.head(5))
# Out:
#                                                      2981761 of 2981853  \
# compound                                                          B1Os1
# auid                                             aflow:b771a4d99e7ddec1
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/HEX/B1Os1...
# spacegroup_relax                                                    187
# Pearson_symbol_relax                                                hP2
#
#                                                      2981762 of 2981853  \
# compound                                                          B2Mg1
# auid                                             aflow:e2edff877e89347a
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/HEX/B2Mg1...
# spacegroup_relax                                                    191
# Pearson_symbol_relax                                                hP3
#
#                                                      2981763 of 2981853  \
# compound                                                          Cr1N1
# auid                                             aflow:3f6ff80616013748
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/FCC/Cr1N1...
# spacegroup_relax                                                    225
# Pearson_symbol_relax                                                cF8
#
#                                                      2981764 of 2981853  \
# compound                                                          B1Tc1
# auid                                             aflow:1ded95025c9807bc
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/HEX/B1Tc1...
# spacegroup_relax                                                    187
# Pearson_symbol_relax                                                hP2
#
#                                                      2981765 of 2981853  \
# compound                                                        B2Co3Y1
# auid                                             aflow:865e8621089a6469
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/HEX/B2Co3...
# spacegroup_relax                                                    191
# Pearson_symbol_relax                                                hP6
#
#                                                      2981766 of 2981853  \
# compound                                                          C1Mo1
# auid                                             aflow:e6168f280fcabded
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/FCC/C1Mo1...
# spacegroup_relax                                                    225
# Pearson_symbol_relax                                                cF8
#
#                                                      2981767 of 2981853  \
# compound                                                            Tc1
# auid                                             aflow:6a87de99cc84ce75
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/FCC/Tc1_I...
# spacegroup_relax                                                    225
# Pearson_symbol_relax                                                cF4
#
#                                                      2981768 of 2981853  \
# compound                                                           C4N8
# auid                                             aflow:bd7933c86d9b4a6c
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/BCT/C1N2_...
# spacegroup_relax                                                    122
# Pearson_symbol_relax                                               tI24
#
#                                                      2981769 of 2981853  \
# compound                                                           B3N3
# auid                                             aflow:cd22e0d75d9681c1
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/HEX/B1N1_...
# spacegroup_relax                                                    160
# Pearson_symbol_relax                                                hR2
#
#                                                      2981770 of 2981853  ...  \
# compound                                                          Al1N1  ...
# auid                                             aflow:85aedc4a778b7e60  ...
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/FCC/Al1N1...  ...
# spacegroup_relax                                                    216  ...
# Pearson_symbol_relax                                                cF8  ...
#
#                                                      2981815 of 2981853  \
# compound                                                          C1Mo1
# auid                                             aflow:877b232d6378c18e
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/HEX/C1Mo1...
# spacegroup_relax                                                    187
# Pearson_symbol_relax                                                hP2
#
#                                                   2981816 of 2981853  \
# compound                                                        C1V1
# auid                                          aflow:8b5f884504829e1b
# aurl                  aflowlib.duke.edu:AFLOWDATA/LIB2_RAW/CV_sv/201
# spacegroup_relax                                                 225
# Pearson_symbol_relax                                             cF8
#
#                                                      2981817 of 2981853  \
# compound                                                             C8
# auid                                             aflow:b09fb2c5d1e939ca
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/ORCC/C1_I...
# spacegroup_relax                                                     65
# Pearson_symbol_relax                                               oS16
#
#                                                      2981818 of 2981853  \
# compound                                                          B2Zr1
# auid                                             aflow:08bf56bf0b207b22
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/HEX/B2Zr1...
# spacegroup_relax                                                    191
# Pearson_symbol_relax                                                hP3
#
#                                                      2981819 of 2981853  \
# compound                                                           C3N4
# auid                                             aflow:02e917f98e603284
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/CUB/C3N4_...
# spacegroup_relax                                                    215
# Pearson_symbol_relax                                                cP7
#
#                                                      2981820 of 2981853  \
# compound                                                          B2Sc1
# auid                                             aflow:1d788038cb5c444e
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/HEX/B2Sc1...
# spacegroup_relax                                                    191
# Pearson_symbol_relax                                                hP3
#
#                                                      2981821 of 2981853  \
# compound                                                          C1Ti1
# auid                                             aflow:dd9ba1426a59901e
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/FCC/C1Ti1...
# spacegroup_relax                                                    225
# Pearson_symbol_relax                                                cF8
#
#                                                      2981822 of 2981853  \
# compound                                                            C16
# auid                                             aflow:d8e58d3bd84cf982
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/ORC/C1_IC...
# spacegroup_relax                                                     62
# Pearson_symbol_relax                                               oP16
#
#                                                      2981823 of 2981853  \
# compound                                                          C1Cr1
# auid                                             aflow:c3cc01a07e4f80e0
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/HEX/C1Cr1...
# spacegroup_relax                                                    187
# Pearson_symbol_relax                                                hP2
#
#                                                      2981824 of 2981853
# compound                                                           B2V1
# auid                                             aflow:75a24ef7ad5fbf92
# aurl                  aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/HEX/B2V1_...
# spacegroup_relax                                                    191
# Pearson_symbol_relax                                                hP3
#
# [5 rows x 64 columns]

# %%
url = (
    "http://aflowlib.duke.edu/search/API/?"
    "agl_thermal_conductivity_300K(!null),"
    "count(*)=*"
)

r = requests.get(url)
data = r.json()

df = pd.DataFrame(data)
print(df.head())

# %%
url = (
    "http://aflowlib.duke.edu/search/API/?"
    "agl_thermal_conductivity_300K(!null),"
    "paging(1)"
)

r = requests.get(url)
data = r.json()

df = pd.DataFrame(data)

# %%
df
# Out:
#                                                                        1 of 5653  \
# compound                                                                     Bi4
# auid                                                      aflow:fadf792d7b321127
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/BCT/Bi1_I...
# agl_thermal_conductivity_300K                                         0.00988102
#
#                                                                        2 of 5653  \
# compound                                                                 Hg33Rb3
# auid                                                      aflow:3a84e674e05ac4e6
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/CUB/Hg11R...
# agl_thermal_conductivity_300K                                          0.0115074
#
#                                                                        3 of 5653  \
# compound                                                                  Hg33K3
# auid                                                      aflow:ac7610d35123f5c5
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/CUB/Hg11K...
# agl_thermal_conductivity_300K                                          0.0118133
#
#                                                                        4 of 5653  \
# compound                                                                 Cs6Hg40
# auid                                                      aflow:978182b72d30a019
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/CUB/Cs3Hg...
# agl_thermal_conductivity_300K                                          0.0137347
#
#                                                                        5 of 5653  \
# compound                                                                   Ag4O2
# auid                                                      aflow:f024f2b3bfd420b0
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/CUB/Ag2O1...
# agl_thermal_conductivity_300K                                          0.0174529
#
#                                                                        6 of 5653  \
# compound                                                                  He8Ne4
# auid                                                      aflow:0c36787efc568915
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/HEX/He2Ne...
# agl_thermal_conductivity_300K                                          0.0423603
#
#                                                                        7 of 5653  \
# compound                                                                Ca16Hg36
# auid                                                      aflow:fe8eeb1e2af8df90
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/CUB/Ca4Hg...
# agl_thermal_conductivity_300K                                          0.0749358
#
#                                                                        8 of 5653  \
# compound                                                                  Cr1Te1
# auid                                                      aflow:53c8683bd5648144
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/FCC/Cr1Te...
# agl_thermal_conductivity_300K                                          0.0805987
#
#                                                                        9 of 5653  \
# compound                                                                 Hg10Pd4
# auid                                                      aflow:4bda491855920812
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/TET/Hg5Pd...
# agl_thermal_conductivity_300K                                          0.0851389
#
#                                                                       10 of 5653  \
# compound                                                                   Hg4K2
# auid                                                      aflow:50b2883feb14cd6e
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/ORCI/Hg2K...
# agl_thermal_conductivity_300K                                          0.0863275
#
#                                ...  \
# compound                       ...
# auid                           ...
# aurl                           ...
# agl_thermal_conductivity_300K  ...
#
#                                                                       55 of 5653  \
# compound                                                              Br24Cs8Te4
# auid                                                      aflow:81a977a0efede30d
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/FCC/Br6Cs...
# agl_thermal_conductivity_300K                                            0.24536
#
#                                                                       56 of 5653  \
# compound                                                                I6Rb2Sn1
# auid                                                      aflow:feee15cf90b253fe
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/FCC/I6Rb2...
# agl_thermal_conductivity_300K                                           0.250113
#
#                                                                       57 of 5653  \
# compound                                                                   Cu4O2
# auid                                                      aflow:f0b1c8b5771c9262
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/CUB/Cu2O1...
# agl_thermal_conductivity_300K                                           0.253177
#
#                                                                       58 of 5653  \
# compound                                                                   V4Zr2
# auid                                                      aflow:190e395abaa79fb2
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/FCC/V2Zr1...
# agl_thermal_conductivity_300K                                           0.256097
#
#                                                                       59 of 5653  \
# compound                                                                  Hg1Pt3
# auid                                                      aflow:7dcd5c1f1a8467d2
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/CUB/Hg1Pt...
# agl_thermal_conductivity_300K                                            0.26108
#
#                                                                       60 of 5653  \
# compound                                                                   O4Pt2
# auid                                                      aflow:947f4a36e26b1a01
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/CUB/O2Pt1...
# agl_thermal_conductivity_300K                                           0.262206
#
#                                                                       61 of 5653  \
# compound                                                                I6Pd1Rb2
# auid                                                      aflow:49f47f6178dea1f9
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/FCC/I6Pd1...
# agl_thermal_conductivity_300K                                           0.263696
#
#                                                                       62 of 5653  \
# compound                                                                 Hg4Sr12
# auid                                                      aflow:b194a22dbd1e7b74
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/ORC/Hg1Sr...
# agl_thermal_conductivity_300K                                            0.26684
#
#                                                                       63 of 5653  \
# compound                                                              As2Rb6Se32
# auid                                                      aflow:f38425f6bc10cbcc
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/FCC/As1Rb...
# agl_thermal_conductivity_300K                                           0.269721
#
#                                                                       64 of 5653
# compound                                                               Ag2Br4Cs2
# auid                                                      aflow:8e1432465df5fab6
# aurl                           aflowlib.duke.edu:AFLOWDATA/ICSD_WEB/ORCC/Ag1B...
# agl_thermal_conductivity_300K                                           0.270806
#
# [4 rows x 64 columns]

# %%
df2 = df[["compound","agl_thermal_conductivity_300K","stoichiometry"]]

# %%
df_final = pd.DataFrame(columns=['compound','agl_thermal_conductivity_300K','stoichiometry'])

# %%
df_final = pd.concat([df_final,df2], ignore_index=True)

# %%
df_final
# Out:
#        compound agl_thermal_conductivity_300K  \
# 0      B8Nb4Ni4                       15.5525
# 1      Al6C6Gd2                       15.5586
# 2         Nd1P1                        15.581
# 3          C2U1                       15.6025
# 4       C2Ge2V4                       15.6237
# ..          ...                           ...
# 123       O4Pt2                      0.262206
# 124    I6Pd1Rb2                      0.263696
# 125     Hg4Sr12                       0.26684
# 126  As2Rb6Se32                      0.269721
# 127   Ag2Br4Cs2                      0.270806
#
#                         stoichiometry
# 0                       0.5,0.25,0.25
# 1    0.42857143,0.42857143,0.14285714
# 2                             0.5,0.5
# 3               0.66666667,0.33333333
# 4                       0.25,0.25,0.5
# ..                                ...
# 123             0.66666667,0.33333333
# 124  0.66666667,0.11111111,0.22222222
# 125                         0.25,0.75
# 126                     0.05,0.15,0.8
# 127                     0.25,0.5,0.25
#
# [128 rows x 3 columns]
